# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()

# %%
# adicionar vértices
G.add_node('exemplo')
G.add_nodes_from(range(1,3))

# adicionar arestas
G.add_edge(1,'exemplo')
G.add_edges_from([(1, 2),(1,3),(3,1),(2,1),('exemplo',1)])
# Out:
# [1, 1, 1, 0, 0]

# %%
nx.draw_networkx(G,node_color = 'b',node_size=1600,with_labels = True)
limits=plt.axis('off') # turn of axis

# %%
G = nx.petersen_graph()
nx.draw_networkx(G,node_color = 'b',node_size=1600,with_labels = True)
limits=plt.axis('off') # turn of axis

# %%
G=nx.erdos_renyi_graph(10,0.4)
# nx.draw_networkx(G,node_color = 'b',node_size=1000,with_labels = True)
nx.draw(G,node_color = 'b',node_size=1000,with_labels=True) 
# limits=plt.axis('off') # turn of axis
