# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()

# %%
G=nx.erdos_renyi_graph(10,0.4)
nx.draw_networkx(G,node_color = 'lime',node_size=1600,with_labels = True)
limits=plt.axis('off')

# %%
G = nx.petersen_graph()
nx.draw_networkx(G,node_color = 'lime',node_size=1600,with_labels = True)
limits=plt.axis('off')
